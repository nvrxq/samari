# %%
from tfm.dataset.sav import *
from tfm.dataset.utils import *

# %%
dataset = AsyncAVDataset("tfm/tests/sav_example")
#frames, masks = dataset[0]
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 dataset = AsyncAVDataset("tfm/tests/sav_example")
#       2 #frames, masks = dataset[0]
#
# File ~/Work/samari/tfm/dataset/sav.py:39, in AsyncAVDataset.__init__(self, sav_dir, binary_task, frames_per_sample, annot_sample_rate, prefetch)
#      36 self.lock = asyncio.Lock()
#      37 self.prefetch_queue = asyncio.Queue()
# ---> 39 self._init_dataset()
#      40 logger.info(f"Found {len(self.files)} files")
#
# File ~/Work/samari/tfm/dataset/sav.py:48, in AsyncAVDataset._init_dataset(self)
#      45     for idx in range(min(self.prefetch, len(self.files))):
#      46         await self._prefetch_item(idx)
# ---> 48 self.loop.run_until_complete(_run_prefetch())
#
# File /usr/lib/python3.12/asyncio/base_events.py:662, in BaseEventLoop.run_until_complete(self, future)
#     651 """Run until the Future is done.
#     652
#     653 If the argument is a coroutine, it is wrapped in a Task.
#    (...)    659 Return the Future's result, or raise its exception.
#     660 """
#     661 self._check_closed()
# --> 662 self._check_running()
#     664 new_task = not futures.isfuture(future)
#     665 future = tasks.ensure_future(future, loop=self)
#
# File /usr/lib/python3.12/asyncio/base_events.py:623, in BaseEventLoop._check_running(self)
#     621     raise RuntimeError('This event loop is already running')
#     622 if events._get_running_loop() is not None:
# --> 623     raise RuntimeError(
#     624         'Cannot run the event loop while another loop is running')
#
# RuntimeError: Cannot run the event loop while another loop is running

# %%
frames, masks = dataset[0]
# Out:
# 2025-04-02 00:42:31,094 - tfm.dataset.sav - DEBUG - Loading data for index 0 synchronously
# 2025-04-02 00:42:31,094 - tfm.dataset.sav - DEBUG - Loading data for index 0: tfm/tests/sav_example/sav_000001.mp4
# 2025-04-02 00:42:31,095 - tfm.dataset.sav - DEBUG - Decoding video: tfm/tests/sav_example/sav_000001.mp4
# 2025-04-02 00:42:31,510 - tfm.dataset.sav - DEBUG - Loading annotations: tfm/tests/sav_example/sav_000001.mp4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 frames, masks = dataset[0]
#
# File ~/Work/samari/tfm/dataset/sav.py:66, in __getitem__(self, index)
#      63     self.data_cache[index] = (frames, annotations)
#      64     logger.debug(f"Prefetched item {index}")
# ---> 66 # Запускаем предзагрузку следующего элемента
#      67 next_index = index + self.prefetch
#      68 if next_index < len(self.files):
#
# File ~/Work/samari/tfm/dataset/sav.py:130, in _load_data(self, index)
#     128 next_index = index + 1
#     129 if next_index < len(self.files):
# --> 130     self.prefetch_queue.put_nowait(self._prefetch_item(next_index))
#     132 return frames[bos:eos], annotations[bos:eos]
#
# KeyboardInterrupt:

# %%
    output_dir = "output_videos"
    os.makedirs(output_dir, exist_ok=True)
    output_video_path = os.path.join(output_dir, "output_video_with_masks.mp4")
    
    create_video_with_masks(dataset, output_video_path, video_index=0)
# Out:
# 2025-04-02 00:05:13,077 - __main__ - INFO - Bos frame idx: 56 Eos frame idx: 88
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 2025-04-02 00:05:13,269 - __main__ - INFO - Video saved to output_videos/output_video_with_masks.mp4

# %%
_, mask = dataset[0]
# Out:
# 2025-04-02 00:05:24,512 - __main__ - INFO - Bos frame idx: 36 Eos frame idx: 68

# %%
import matplotlib.pyplot as plt
plt.imshow(mask[2])
